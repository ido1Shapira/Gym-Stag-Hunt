# %%
import numpy as np
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

import shutil

# ! pip install split-folders
import splitfolders

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

import matplotlib.pyplot as plt

rs = 42
def reset_random_seeds(rs):
   os.environ['PYTHONHASHSEED']=str(rs)
   tf.random.set_seed(rs)
   np.random.seed(rs)
   random.seed(rs)
reset_random_seeds(rs)

# %% [markdown]
# remove prev saved database:

# %%
dir_path = './data/humanModel/dataset_v0_split'
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)
else:
    print("File not found in the directory")

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## Split into train , test data

# %%
# train, test split
splitfolders.ratio('./data/humanModel/dataset_v0/', output=dir_path, ratio=(0.85, 0.15))
# Out:
# Copying files: 8160 files [00:00, 17060.46 files/s]

# %% [markdown]
# ### Preprocessing the Training set

# %%
batch_size = 128
IMG_SIZE = 5

datagen = ImageDataGenerator(rescale = 1./255)
train = datagen.flow_from_directory((dir_path+'/train'),
                                          target_size = (IMG_SIZE,IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')

test = datagen.flow_from_directory((dir_path+'/val'),
                                            target_size = (IMG_SIZE, IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')
# Out:
# Found 6934 images belonging to 4 classes.
# Found 1226 images belonging to 4 classes.

# %% [markdown]
# ## View some data

# %%
num_classes = 4

model = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=[IMG_SIZE,IMG_SIZE,3]),
  layers.Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  # layers.MaxPooling2D(),
  layers.Conv2D(8, 2, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 5, 5, 4)           112
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 8)           296
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 8)           264
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                12864
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 13,796
# Trainable params: 13,796
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=175
history = model.fit(
  train,
  validation_data=test,
  epochs=epochs
)
# Out:
# Epoch 1/175
# 55/55 [==============================] - 2s 19ms/step - loss: 1.4693 - accuracy: 0.2870 - val_loss: 1.4399 - val_accuracy: 0.3140
# Epoch 2/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.4128 - accuracy: 0.3187 - val_loss: 1.3545 - val_accuracy: 0.3891
# Epoch 3/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.3289 - accuracy: 0.3976 - val_loss: 1.2665 - val_accuracy: 0.4356
# Epoch 4/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.2705 - accuracy: 0.4445 - val_loss: 1.2222 - val_accuracy: 0.4715
# Epoch 5/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.2421 - accuracy: 0.4448 - val_loss: 1.2055 - val_accuracy: 0.4796
# Epoch 6/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2184 - accuracy: 0.4650 - val_loss: 1.1772 - val_accuracy: 0.4910
# Epoch 7/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2071 - accuracy: 0.4680 - val_loss: 1.1725 - val_accuracy: 0.5000
# Epoch 8/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.2000 - accuracy: 0.4674 - val_loss: 1.1578 - val_accuracy: 0.5057
# Epoch 9/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1856 - accuracy: 0.4713 - val_loss: 1.1521 - val_accuracy: 0.5033
# Epoch 10/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1804 - accuracy: 0.4837 - val_loss: 1.1376 - val_accuracy: 0.5163
# Epoch 11/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1689 - accuracy: 0.4833 - val_loss: 1.1392 - val_accuracy: 0.5310
# Epoch 12/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1645 - accuracy: 0.4919 - val_loss: 1.1273 - val_accuracy: 0.5147
# Epoch 13/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1612 - accuracy: 0.4833 - val_loss: 1.1269 - val_accuracy: 0.5212
# Epoch 14/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1529 - accuracy: 0.4987 - val_loss: 1.1237 - val_accuracy: 0.5269
# Epoch 15/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1482 - accuracy: 0.4934 - val_loss: 1.1175 - val_accuracy: 0.5228
# Epoch 16/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1460 - accuracy: 0.4981 - val_loss: 1.1171 - val_accuracy: 0.5171
# Epoch 17/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1402 - accuracy: 0.4988 - val_loss: 1.1193 - val_accuracy: 0.5188
# Epoch 18/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1406 - accuracy: 0.4965 - val_loss: 1.1088 - val_accuracy: 0.5285
# Epoch 19/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1324 - accuracy: 0.5061 - val_loss: 1.1087 - val_accuracy: 0.5277
# Epoch 20/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1324 - accuracy: 0.5043 - val_loss: 1.1067 - val_accuracy: 0.5285
# Epoch 21/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1321 - accuracy: 0.4981 - val_loss: 1.1022 - val_accuracy: 0.5432
# Epoch 22/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1245 - accuracy: 0.5072 - val_loss: 1.1016 - val_accuracy: 0.5212
# Epoch 23/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1218 - accuracy: 0.5062 - val_loss: 1.0987 - val_accuracy: 0.5416
# Epoch 24/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1189 - accuracy: 0.5058 - val_loss: 1.0948 - val_accuracy: 0.5400
# Epoch 25/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1186 - accuracy: 0.5153 - val_loss: 1.0916 - val_accuracy: 0.5334
# Epoch 26/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.1085 - accuracy: 0.5179 - val_loss: 1.0933 - val_accuracy: 0.5408
# Epoch 27/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1145 - accuracy: 0.5091 - val_loss: 1.0908 - val_accuracy: 0.5294
# Epoch 28/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1088 - accuracy: 0.5186 - val_loss: 1.0905 - val_accuracy: 0.5367
# Epoch 29/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1084 - accuracy: 0.5192 - val_loss: 1.0923 - val_accuracy: 0.5245
# Epoch 30/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1072 - accuracy: 0.5153 - val_loss: 1.0839 - val_accuracy: 0.5546
# Epoch 31/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0986 - accuracy: 0.5193 - val_loss: 1.0857 - val_accuracy: 0.5481
# Epoch 32/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1026 - accuracy: 0.5203 - val_loss: 1.0824 - val_accuracy: 0.5351
# Epoch 33/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.1043 - accuracy: 0.5206 - val_loss: 1.0823 - val_accuracy: 0.5351
# Epoch 34/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0984 - accuracy: 0.5144 - val_loss: 1.0826 - val_accuracy: 0.5269
# Epoch 35/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0949 - accuracy: 0.5185 - val_loss: 1.0790 - val_accuracy: 0.5334
# Epoch 36/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0951 - accuracy: 0.5237 - val_loss: 1.0808 - val_accuracy: 0.5432
# Epoch 37/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0848 - accuracy: 0.5299 - val_loss: 1.0751 - val_accuracy: 0.5432
# Epoch 38/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0859 - accuracy: 0.5303 - val_loss: 1.0802 - val_accuracy: 0.5269
# Epoch 39/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0914 - accuracy: 0.5312 - val_loss: 1.0735 - val_accuracy: 0.5440
# Epoch 40/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0893 - accuracy: 0.5322 - val_loss: 1.0755 - val_accuracy: 0.5432
# Epoch 41/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0873 - accuracy: 0.5251 - val_loss: 1.0705 - val_accuracy: 0.5343
# Epoch 42/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0817 - accuracy: 0.5345 - val_loss: 1.0685 - val_accuracy: 0.5506
# Epoch 43/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0796 - accuracy: 0.5352 - val_loss: 1.0712 - val_accuracy: 0.5481
# Epoch 44/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0818 - accuracy: 0.5274 - val_loss: 1.0668 - val_accuracy: 0.5530
# Epoch 45/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0790 - accuracy: 0.5301 - val_loss: 1.0655 - val_accuracy: 0.5579
# Epoch 46/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0809 - accuracy: 0.5268 - val_loss: 1.0640 - val_accuracy: 0.5653
# Epoch 47/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0758 - accuracy: 0.5389 - val_loss: 1.0729 - val_accuracy: 0.5546
# Epoch 48/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0763 - accuracy: 0.5310 - val_loss: 1.0609 - val_accuracy: 0.5620
# Epoch 49/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0706 - accuracy: 0.5388 - val_loss: 1.0611 - val_accuracy: 0.5506
# Epoch 50/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0682 - accuracy: 0.5342 - val_loss: 1.0635 - val_accuracy: 0.5546
# Epoch 51/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0679 - accuracy: 0.5436 - val_loss: 1.0595 - val_accuracy: 0.5628
# Epoch 52/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0683 - accuracy: 0.5407 - val_loss: 1.0588 - val_accuracy: 0.5661
# Epoch 53/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0639 - accuracy: 0.5397 - val_loss: 1.0534 - val_accuracy: 0.5710
# Epoch 54/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0649 - accuracy: 0.5470 - val_loss: 1.0510 - val_accuracy: 0.5612
# Epoch 55/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0631 - accuracy: 0.5457 - val_loss: 1.0570 - val_accuracy: 0.5742
# Epoch 56/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0657 - accuracy: 0.5392 - val_loss: 1.0583 - val_accuracy: 0.5587
# Epoch 57/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0598 - accuracy: 0.5524 - val_loss: 1.0569 - val_accuracy: 0.5628
# Epoch 58/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0574 - accuracy: 0.5548 - val_loss: 1.0523 - val_accuracy: 0.5701
# Epoch 59/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0579 - accuracy: 0.5480 - val_loss: 1.0577 - val_accuracy: 0.5620
# Epoch 60/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0604 - accuracy: 0.5482 - val_loss: 1.0507 - val_accuracy: 0.5701
# Epoch 61/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0529 - accuracy: 0.5464 - val_loss: 1.0559 - val_accuracy: 0.5620
# Epoch 62/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0584 - accuracy: 0.5489 - val_loss: 1.0488 - val_accuracy: 0.5653
# Epoch 63/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0579 - accuracy: 0.5464 - val_loss: 1.0491 - val_accuracy: 0.5653
# Epoch 64/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0491 - accuracy: 0.5490 - val_loss: 1.0564 - val_accuracy: 0.5489
# Epoch 65/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0536 - accuracy: 0.5526 - val_loss: 1.0549 - val_accuracy: 0.5644
# Epoch 66/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0524 - accuracy: 0.5542 - val_loss: 1.0486 - val_accuracy: 0.5701
# Epoch 67/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0503 - accuracy: 0.5555 - val_loss: 1.0439 - val_accuracy: 0.5775
# Epoch 68/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0533 - accuracy: 0.5508 - val_loss: 1.0453 - val_accuracy: 0.5718
# Epoch 69/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0534 - accuracy: 0.5545 - val_loss: 1.0486 - val_accuracy: 0.5644
# Epoch 70/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0498 - accuracy: 0.5593 - val_loss: 1.0454 - val_accuracy: 0.5604
# Epoch 71/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0481 - accuracy: 0.5541 - val_loss: 1.0482 - val_accuracy: 0.5710
# Epoch 72/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0440 - accuracy: 0.5577 - val_loss: 1.0400 - val_accuracy: 0.5783
# Epoch 73/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0461 - accuracy: 0.5588 - val_loss: 1.0416 - val_accuracy: 0.5832
# Epoch 74/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0421 - accuracy: 0.5650 - val_loss: 1.0508 - val_accuracy: 0.5571
# Epoch 75/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0418 - accuracy: 0.5587 - val_loss: 1.0375 - val_accuracy: 0.5767
# Epoch 76/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0386 - accuracy: 0.5636 - val_loss: 1.0444 - val_accuracy: 0.5701
# Epoch 77/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0463 - accuracy: 0.5586 - val_loss: 1.0411 - val_accuracy: 0.5791
# Epoch 78/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0396 - accuracy: 0.5596 - val_loss: 1.0367 - val_accuracy: 0.5824
# Epoch 79/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0393 - accuracy: 0.5623 - val_loss: 1.0341 - val_accuracy: 0.5701
# Epoch 80/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0359 - accuracy: 0.5676 - val_loss: 1.0375 - val_accuracy: 0.5701
# Epoch 81/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0409 - accuracy: 0.5630 - val_loss: 1.0377 - val_accuracy: 0.5824
# Epoch 82/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0372 - accuracy: 0.5640 - val_loss: 1.0353 - val_accuracy: 0.5808
# Epoch 83/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0278 - accuracy: 0.5711 - val_loss: 1.0518 - val_accuracy: 0.5522
# Epoch 84/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0370 - accuracy: 0.5611 - val_loss: 1.0355 - val_accuracy: 0.5742
# Epoch 85/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0299 - accuracy: 0.5665 - val_loss: 1.0364 - val_accuracy: 0.5808
# Epoch 86/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0318 - accuracy: 0.5643 - val_loss: 1.0316 - val_accuracy: 0.5742
# Epoch 87/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0292 - accuracy: 0.5672 - val_loss: 1.0311 - val_accuracy: 0.5767
# Epoch 88/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0240 - accuracy: 0.5748 - val_loss: 1.0418 - val_accuracy: 0.5604
# Epoch 89/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0315 - accuracy: 0.5639 - val_loss: 1.0388 - val_accuracy: 0.5767
# Epoch 90/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0291 - accuracy: 0.5737 - val_loss: 1.0321 - val_accuracy: 0.5742
# Epoch 91/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0319 - accuracy: 0.5672 - val_loss: 1.0346 - val_accuracy: 0.5620
# Epoch 92/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0250 - accuracy: 0.5691 - val_loss: 1.0336 - val_accuracy: 0.5840
# Epoch 93/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0199 - accuracy: 0.5736 - val_loss: 1.0334 - val_accuracy: 0.5653
# Epoch 94/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0216 - accuracy: 0.5774 - val_loss: 1.0293 - val_accuracy: 0.5816
# Epoch 95/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0262 - accuracy: 0.5792 - val_loss: 1.0307 - val_accuracy: 0.5726
# Epoch 96/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.0236 - accuracy: 0.5737 - val_loss: 1.0342 - val_accuracy: 0.5759
# Epoch 97/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0237 - accuracy: 0.5733 - val_loss: 1.0225 - val_accuracy: 0.5840
# Epoch 98/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0207 - accuracy: 0.5718 - val_loss: 1.0266 - val_accuracy: 0.5816
# Epoch 99/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0091 - accuracy: 0.5798 - val_loss: 1.0271 - val_accuracy: 0.5742
# Epoch 100/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0195 - accuracy: 0.5740 - val_loss: 1.0283 - val_accuracy: 0.5775
# Epoch 101/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0157 - accuracy: 0.5800 - val_loss: 1.0270 - val_accuracy: 0.5889
# Epoch 102/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0160 - accuracy: 0.5792 - val_loss: 1.0266 - val_accuracy: 0.5759
# Epoch 103/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0156 - accuracy: 0.5803 - val_loss: 1.0278 - val_accuracy: 0.5783
# Epoch 104/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0165 - accuracy: 0.5836 - val_loss: 1.0263 - val_accuracy: 0.5734
# Epoch 105/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0181 - accuracy: 0.5764 - val_loss: 1.0275 - val_accuracy: 0.5644
# Epoch 106/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0107 - accuracy: 0.5835 - val_loss: 1.0239 - val_accuracy: 0.5742
# Epoch 107/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0138 - accuracy: 0.5707 - val_loss: 1.0252 - val_accuracy: 0.5693
# Epoch 108/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0097 - accuracy: 0.5839 - val_loss: 1.0212 - val_accuracy: 0.5856
# Epoch 109/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0077 - accuracy: 0.5815 - val_loss: 1.0207 - val_accuracy: 0.5856
# Epoch 110/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0079 - accuracy: 0.5838 - val_loss: 1.0282 - val_accuracy: 0.5767
# Epoch 111/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0092 - accuracy: 0.5818 - val_loss: 1.0220 - val_accuracy: 0.5873
# Epoch 112/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0119 - accuracy: 0.5832 - val_loss: 1.0256 - val_accuracy: 0.5701
# Epoch 113/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0112 - accuracy: 0.5834 - val_loss: 1.0234 - val_accuracy: 0.5759
# Epoch 114/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0085 - accuracy: 0.5842 - val_loss: 1.0195 - val_accuracy: 0.5767
# Epoch 115/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9987 - accuracy: 0.5860 - val_loss: 1.0238 - val_accuracy: 0.5824
# Epoch 116/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0078 - accuracy: 0.5877 - val_loss: 1.0210 - val_accuracy: 0.5750
# Epoch 117/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0030 - accuracy: 0.5936 - val_loss: 1.0181 - val_accuracy: 0.5791
# Epoch 118/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9962 - accuracy: 0.5920 - val_loss: 1.0140 - val_accuracy: 0.5840
# Epoch 119/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0088 - accuracy: 0.5897 - val_loss: 1.0193 - val_accuracy: 0.5710
# Epoch 120/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0104 - accuracy: 0.5874 - val_loss: 1.0159 - val_accuracy: 0.5759
# Epoch 121/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0041 - accuracy: 0.5917 - val_loss: 1.0159 - val_accuracy: 0.5897
# Epoch 122/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0038 - accuracy: 0.5861 - val_loss: 1.0192 - val_accuracy: 0.5693
# Epoch 123/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0018 - accuracy: 0.5910 - val_loss: 1.0219 - val_accuracy: 0.5816
# Epoch 124/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9957 - accuracy: 0.5958 - val_loss: 1.0175 - val_accuracy: 0.5742
# Epoch 125/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9984 - accuracy: 0.5916 - val_loss: 1.0174 - val_accuracy: 0.5873
# Epoch 126/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9939 - accuracy: 0.5982 - val_loss: 1.0167 - val_accuracy: 0.5897
# Epoch 127/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9903 - accuracy: 0.5955 - val_loss: 1.0208 - val_accuracy: 0.5962
# Epoch 128/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9898 - accuracy: 0.5953 - val_loss: 1.0187 - val_accuracy: 0.5628
# Epoch 129/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9925 - accuracy: 0.5999 - val_loss: 1.0206 - val_accuracy: 0.5791
# Epoch 130/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9975 - accuracy: 0.5945 - val_loss: 1.0211 - val_accuracy: 0.5759
# Epoch 131/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9931 - accuracy: 0.5978 - val_loss: 1.0204 - val_accuracy: 0.5865
# Epoch 132/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9948 - accuracy: 0.5986 - val_loss: 1.0251 - val_accuracy: 0.5832
# Epoch 133/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9900 - accuracy: 0.6024 - val_loss: 1.0190 - val_accuracy: 0.5979
# Epoch 134/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9813 - accuracy: 0.6067 - val_loss: 1.0200 - val_accuracy: 0.5856
# Epoch 135/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9993 - accuracy: 0.5919 - val_loss: 1.0212 - val_accuracy: 0.5783
# Epoch 136/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9938 - accuracy: 0.5976 - val_loss: 1.0183 - val_accuracy: 0.5962
# Epoch 137/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9960 - accuracy: 0.5998 - val_loss: 1.0198 - val_accuracy: 0.5726
# Epoch 138/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9887 - accuracy: 0.5981 - val_loss: 1.0174 - val_accuracy: 0.5832
# Epoch 139/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9863 - accuracy: 0.6051 - val_loss: 1.0197 - val_accuracy: 0.5922
# Epoch 140/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9905 - accuracy: 0.5966 - val_loss: 1.0135 - val_accuracy: 0.5922
# Epoch 141/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9901 - accuracy: 0.5956 - val_loss: 1.0200 - val_accuracy: 0.5718
# Epoch 142/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9840 - accuracy: 0.6066 - val_loss: 1.0150 - val_accuracy: 0.5922
# Epoch 143/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9868 - accuracy: 0.6015 - val_loss: 1.0289 - val_accuracy: 0.5677
# Epoch 144/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9810 - accuracy: 0.6059 - val_loss: 1.0129 - val_accuracy: 0.5750
# Epoch 145/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9761 - accuracy: 0.6057 - val_loss: 1.0188 - val_accuracy: 0.5710
# Epoch 146/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9867 - accuracy: 0.6014 - val_loss: 1.0122 - val_accuracy: 0.5775
# Epoch 147/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9786 - accuracy: 0.6047 - val_loss: 1.0156 - val_accuracy: 0.5718
# Epoch 148/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9815 - accuracy: 0.6048 - val_loss: 1.0158 - val_accuracy: 0.5669
# Epoch 149/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9833 - accuracy: 0.6072 - val_loss: 1.0125 - val_accuracy: 0.5914
# Epoch 150/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9769 - accuracy: 0.6109 - val_loss: 1.0138 - val_accuracy: 0.5767
# Epoch 151/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9765 - accuracy: 0.6102 - val_loss: 1.0182 - val_accuracy: 0.5767
# Epoch 152/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9790 - accuracy: 0.6020 - val_loss: 1.0178 - val_accuracy: 0.5783
# Epoch 153/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9829 - accuracy: 0.6082 - val_loss: 1.0125 - val_accuracy: 0.5848
# Epoch 154/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9775 - accuracy: 0.6080 - val_loss: 1.0139 - val_accuracy: 0.5791
# Epoch 155/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9773 - accuracy: 0.6112 - val_loss: 1.0078 - val_accuracy: 0.6020
# Epoch 156/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9800 - accuracy: 0.5995 - val_loss: 1.0136 - val_accuracy: 0.5889
# Epoch 157/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9781 - accuracy: 0.6050 - val_loss: 1.0071 - val_accuracy: 0.5971
# Epoch 158/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9741 - accuracy: 0.6054 - val_loss: 1.0176 - val_accuracy: 0.5930
# Epoch 159/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9761 - accuracy: 0.6082 - val_loss: 1.0080 - val_accuracy: 0.5881
# Epoch 160/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9701 - accuracy: 0.6148 - val_loss: 1.0064 - val_accuracy: 0.5995
# Epoch 161/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9691 - accuracy: 0.6138 - val_loss: 1.0081 - val_accuracy: 0.5954
# Epoch 162/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9626 - accuracy: 0.6177 - val_loss: 1.0080 - val_accuracy: 0.5962
# Epoch 163/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9718 - accuracy: 0.6121 - val_loss: 1.0077 - val_accuracy: 0.5856
# Epoch 164/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9691 - accuracy: 0.6119 - val_loss: 1.0146 - val_accuracy: 0.5881
# Epoch 165/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9690 - accuracy: 0.6154 - val_loss: 1.0062 - val_accuracy: 0.5987
# Epoch 166/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9632 - accuracy: 0.6135 - val_loss: 1.0152 - val_accuracy: 0.5889
# Epoch 167/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9637 - accuracy: 0.6194 - val_loss: 1.0143 - val_accuracy: 0.5946
# Epoch 168/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9671 - accuracy: 0.6121 - val_loss: 1.0057 - val_accuracy: 0.5914
# Epoch 169/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9729 - accuracy: 0.6112 - val_loss: 1.0159 - val_accuracy: 0.5873
# Epoch 170/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9714 - accuracy: 0.6092 - val_loss: 1.0175 - val_accuracy: 0.5881
# Epoch 171/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9632 - accuracy: 0.6184 - val_loss: 1.0140 - val_accuracy: 0.6003
# Epoch 172/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9682 - accuracy: 0.6154 - val_loss: 1.0118 - val_accuracy: 0.5954
# Epoch 173/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9659 - accuracy: 0.6210 - val_loss: 1.0126 - val_accuracy: 0.6020
# Epoch 174/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9653 - accuracy: 0.6184 - val_loss: 1.0149 - val_accuracy: 0.5995
# Epoch 175/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9653 - accuracy: 0.6184 - val_loss: 1.0092 - val_accuracy: 0.6011

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test)
print('Test accuracy :', accuracy)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0092 - accuracy: 0.6011
# Test accuracy : 0.6011419296264648

# %%
# Save the weights model.
model.save('./data/humanModel/model_v0.h5')

# %%
# save model in js format
# import tensorflowjs as tfjs
# tfjs.converters.save_keras_model(model, 'data/humanModel/js_model_v0')

# %%
# new_model = tf.keras.models.load_model('./data/humanModel/mode_v0')

# # Check its architecture
# new_model.summary()

# %% [markdown]
# ### Predict on new data

# %%
path = "./data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png"

img = keras.preprocessing.image.load_img(
    path, target_size=(IMG_SIZE, IMG_SIZE)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
img_array = img_array/255
predictions = model.predict(img_array)[0]

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(np.argmax(predictions), 100 * np.max(predictions))
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2859150/1618442636.py in <module>
#       2
#       3 img = keras.preprocessing.image.load_img(
# ----> 4     path, target_size=(IMG_SIZE, IMG_SIZE)
#       5 )
#       6 img_array = keras.preprocessing.image.img_to_array(img)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/humanModel_v0_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png'
