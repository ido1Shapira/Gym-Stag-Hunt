# %%
import numpy as np
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

import shutil

# ! pip install split-folders
import splitfolders

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

import matplotlib.pyplot as plt

rs = 42
def reset_random_seeds(rs):
   os.environ['PYTHONHASHSEED']=str(rs)
   tf.random.set_seed(rs)
   np.random.seed(rs)
   random.seed(rs)
reset_random_seeds(rs)

# %% [markdown]
# remove prev saved database:

# %%
dir_path = './data/humanModel/dataset_split'
if os.path.exists(dir_path):
    shutil.rmtree(dir_path)
else:
    print("File not found in the directory")

# %% [markdown]
# # Part 1 - Data Preprocessing

# %% [markdown]
# ## Split into train , test data

# %%
# train, test split
splitfolders.ratio('./data/humanModel/dataset/', output=dir_path, ratio=(0.85, 0.15))
# Out:
# Copying files: 8160 files [00:00, 11878.13 files/s]

# %% [markdown]
# ### Preprocessing the Training set

# %%
batch_size = 128
IMG_SIZE = 5

datagen = ImageDataGenerator(rescale = 1./255)
train = datagen.flow_from_directory((dir_path+'/train'),
                                          target_size = (IMG_SIZE,IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')

test = datagen.flow_from_directory((dir_path+'/val'),
                                            target_size = (IMG_SIZE, IMG_SIZE), batch_size = batch_size, seed=rs, class_mode='sparse')
# Out:
# Found 6934 images belonging to 4 classes.
# Found 1226 images belonging to 4 classes.

# %% [markdown]
# ## View some data

# %%
num_classes = 4

model = Sequential([
  layers.Conv2D(4, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=[IMG_SIZE,IMG_SIZE,3]),
  layers.Conv2D(8, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  # layers.MaxPooling2D(),
  layers.Conv2D(8, 2, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 5, 5, 4)           112
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 8)           296
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 8)           264
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                12864
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 13,796
# Trainable params: 13,796
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=175
history = model.fit(
  train,
  validation_data=test,
  epochs=epochs
)
# Out:
# Epoch 1/175
# 55/55 [==============================] - 2s 20ms/step - loss: 1.4693 - accuracy: 0.2870 - val_loss: 1.4399 - val_accuracy: 0.3140
# Epoch 2/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.4128 - accuracy: 0.3187 - val_loss: 1.3545 - val_accuracy: 0.3891
# Epoch 3/175
# 55/55 [==============================] - 1s 19ms/step - loss: 1.3289 - accuracy: 0.3976 - val_loss: 1.2665 - val_accuracy: 0.4356
# Epoch 4/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.2705 - accuracy: 0.4445 - val_loss: 1.2222 - val_accuracy: 0.4715
# Epoch 5/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2421 - accuracy: 0.4448 - val_loss: 1.2055 - val_accuracy: 0.4796
# Epoch 6/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2184 - accuracy: 0.4650 - val_loss: 1.1772 - val_accuracy: 0.4910
# Epoch 7/175
# 55/55 [==============================] - 1s 20ms/step - loss: 1.2071 - accuracy: 0.4680 - val_loss: 1.1725 - val_accuracy: 0.5000
# Epoch 8/175
# 55/55 [==============================] - 1s 24ms/step - loss: 1.2000 - accuracy: 0.4674 - val_loss: 1.1578 - val_accuracy: 0.5057
# Epoch 9/175
# 55/55 [==============================] - 1s 22ms/step - loss: 1.1856 - accuracy: 0.4713 - val_loss: 1.1521 - val_accuracy: 0.5033
# Epoch 10/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1804 - accuracy: 0.4837 - val_loss: 1.1376 - val_accuracy: 0.5163
# Epoch 11/175
# 55/55 [==============================] - 1s 22ms/step - loss: 1.1689 - accuracy: 0.4833 - val_loss: 1.1392 - val_accuracy: 0.5310
# Epoch 12/175
# 55/55 [==============================] - 1s 26ms/step - loss: 1.1645 - accuracy: 0.4919 - val_loss: 1.1273 - val_accuracy: 0.5147
# Epoch 13/175
# 55/55 [==============================] - 1s 27ms/step - loss: 1.1612 - accuracy: 0.4833 - val_loss: 1.1269 - val_accuracy: 0.5212
# Epoch 14/175
# 55/55 [==============================] - 1s 26ms/step - loss: 1.1529 - accuracy: 0.4987 - val_loss: 1.1237 - val_accuracy: 0.5269
# Epoch 15/175
# 55/55 [==============================] - 1s 26ms/step - loss: 1.1482 - accuracy: 0.4934 - val_loss: 1.1175 - val_accuracy: 0.5228
# Epoch 16/175
# 55/55 [==============================] - 1s 25ms/step - loss: 1.1461 - accuracy: 0.4983 - val_loss: 1.1172 - val_accuracy: 0.5171
# Epoch 17/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1401 - accuracy: 0.4994 - val_loss: 1.1193 - val_accuracy: 0.5171
# Epoch 18/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1406 - accuracy: 0.4964 - val_loss: 1.1086 - val_accuracy: 0.5302
# Epoch 19/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1324 - accuracy: 0.5049 - val_loss: 1.1090 - val_accuracy: 0.5261
# Epoch 20/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1327 - accuracy: 0.5040 - val_loss: 1.1066 - val_accuracy: 0.5302
# Epoch 21/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1321 - accuracy: 0.4981 - val_loss: 1.1026 - val_accuracy: 0.5408
# Epoch 22/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1245 - accuracy: 0.5076 - val_loss: 1.1015 - val_accuracy: 0.5245
# Epoch 23/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1222 - accuracy: 0.5062 - val_loss: 1.0987 - val_accuracy: 0.5457
# Epoch 24/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1189 - accuracy: 0.5042 - val_loss: 1.0949 - val_accuracy: 0.5375
# Epoch 25/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.1184 - accuracy: 0.5146 - val_loss: 1.0916 - val_accuracy: 0.5334
# Epoch 26/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1082 - accuracy: 0.5186 - val_loss: 1.0939 - val_accuracy: 0.5416
# Epoch 27/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1145 - accuracy: 0.5091 - val_loss: 1.0907 - val_accuracy: 0.5269
# Epoch 28/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1088 - accuracy: 0.5190 - val_loss: 1.0906 - val_accuracy: 0.5367
# Epoch 29/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1084 - accuracy: 0.5177 - val_loss: 1.0932 - val_accuracy: 0.5228
# Epoch 30/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1070 - accuracy: 0.5138 - val_loss: 1.0844 - val_accuracy: 0.5522
# Epoch 31/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0991 - accuracy: 0.5192 - val_loss: 1.0872 - val_accuracy: 0.5473
# Epoch 32/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1028 - accuracy: 0.5195 - val_loss: 1.0820 - val_accuracy: 0.5359
# Epoch 33/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.1046 - accuracy: 0.5211 - val_loss: 1.0826 - val_accuracy: 0.5343
# Epoch 34/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0983 - accuracy: 0.5137 - val_loss: 1.0824 - val_accuracy: 0.5245
# Epoch 35/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0953 - accuracy: 0.5198 - val_loss: 1.0794 - val_accuracy: 0.5294
# Epoch 36/175
# 55/55 [==============================] - 1s 19ms/step - loss: 1.0953 - accuracy: 0.5219 - val_loss: 1.0807 - val_accuracy: 0.5416
# Epoch 37/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0841 - accuracy: 0.5296 - val_loss: 1.0752 - val_accuracy: 0.5416
# Epoch 38/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0857 - accuracy: 0.5307 - val_loss: 1.0790 - val_accuracy: 0.5310
# Epoch 39/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0914 - accuracy: 0.5274 - val_loss: 1.0741 - val_accuracy: 0.5416
# Epoch 40/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0892 - accuracy: 0.5307 - val_loss: 1.0758 - val_accuracy: 0.5375
# Epoch 41/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0869 - accuracy: 0.5261 - val_loss: 1.0707 - val_accuracy: 0.5400
# Epoch 42/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0816 - accuracy: 0.5343 - val_loss: 1.0691 - val_accuracy: 0.5546
# Epoch 43/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0805 - accuracy: 0.5356 - val_loss: 1.0710 - val_accuracy: 0.5465
# Epoch 44/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0820 - accuracy: 0.5274 - val_loss: 1.0674 - val_accuracy: 0.5489
# Epoch 45/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0793 - accuracy: 0.5314 - val_loss: 1.0657 - val_accuracy: 0.5571
# Epoch 46/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0810 - accuracy: 0.5291 - val_loss: 1.0638 - val_accuracy: 0.5677
# Epoch 47/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0758 - accuracy: 0.5388 - val_loss: 1.0714 - val_accuracy: 0.5506
# Epoch 48/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0758 - accuracy: 0.5297 - val_loss: 1.0593 - val_accuracy: 0.5636
# Epoch 49/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0710 - accuracy: 0.5389 - val_loss: 1.0609 - val_accuracy: 0.5522
# Epoch 50/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0680 - accuracy: 0.5337 - val_loss: 1.0640 - val_accuracy: 0.5579
# Epoch 51/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0675 - accuracy: 0.5438 - val_loss: 1.0603 - val_accuracy: 0.5669
# Epoch 52/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0686 - accuracy: 0.5379 - val_loss: 1.0603 - val_accuracy: 0.5644
# Epoch 53/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0641 - accuracy: 0.5392 - val_loss: 1.0537 - val_accuracy: 0.5644
# Epoch 54/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0653 - accuracy: 0.5466 - val_loss: 1.0519 - val_accuracy: 0.5620
# Epoch 55/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0630 - accuracy: 0.5444 - val_loss: 1.0571 - val_accuracy: 0.5734
# Epoch 56/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0658 - accuracy: 0.5404 - val_loss: 1.0583 - val_accuracy: 0.5555
# Epoch 57/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0598 - accuracy: 0.5525 - val_loss: 1.0558 - val_accuracy: 0.5653
# Epoch 58/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0568 - accuracy: 0.5565 - val_loss: 1.0534 - val_accuracy: 0.5693
# Epoch 59/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0581 - accuracy: 0.5495 - val_loss: 1.0574 - val_accuracy: 0.5669
# Epoch 60/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0609 - accuracy: 0.5482 - val_loss: 1.0499 - val_accuracy: 0.5701
# Epoch 61/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.0537 - accuracy: 0.5464 - val_loss: 1.0554 - val_accuracy: 0.5653
# Epoch 62/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.0583 - accuracy: 0.5499 - val_loss: 1.0497 - val_accuracy: 0.5612
# Epoch 63/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0577 - accuracy: 0.5456 - val_loss: 1.0486 - val_accuracy: 0.5636
# Epoch 64/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0493 - accuracy: 0.5482 - val_loss: 1.0567 - val_accuracy: 0.5555
# Epoch 65/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0535 - accuracy: 0.5548 - val_loss: 1.0540 - val_accuracy: 0.5628
# Epoch 66/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0531 - accuracy: 0.5554 - val_loss: 1.0485 - val_accuracy: 0.5775
# Epoch 67/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0503 - accuracy: 0.5590 - val_loss: 1.0438 - val_accuracy: 0.5848
# Epoch 68/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0525 - accuracy: 0.5522 - val_loss: 1.0460 - val_accuracy: 0.5742
# Epoch 69/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0534 - accuracy: 0.5552 - val_loss: 1.0481 - val_accuracy: 0.5636
# Epoch 70/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.0491 - accuracy: 0.5552 - val_loss: 1.0450 - val_accuracy: 0.5693
# Epoch 71/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0488 - accuracy: 0.5506 - val_loss: 1.0489 - val_accuracy: 0.5653
# Epoch 72/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0442 - accuracy: 0.5560 - val_loss: 1.0397 - val_accuracy: 0.5783
# Epoch 73/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0457 - accuracy: 0.5580 - val_loss: 1.0403 - val_accuracy: 0.5783
# Epoch 74/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0427 - accuracy: 0.5642 - val_loss: 1.0496 - val_accuracy: 0.5636
# Epoch 75/175
# 55/55 [==============================] - 1s 17ms/step - loss: 1.0417 - accuracy: 0.5573 - val_loss: 1.0365 - val_accuracy: 0.5759
# Epoch 76/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0381 - accuracy: 0.5649 - val_loss: 1.0444 - val_accuracy: 0.5759
# Epoch 77/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0454 - accuracy: 0.5581 - val_loss: 1.0409 - val_accuracy: 0.5783
# Epoch 78/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0398 - accuracy: 0.5591 - val_loss: 1.0385 - val_accuracy: 0.5791
# Epoch 79/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0395 - accuracy: 0.5601 - val_loss: 1.0337 - val_accuracy: 0.5783
# Epoch 80/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0357 - accuracy: 0.5675 - val_loss: 1.0368 - val_accuracy: 0.5775
# Epoch 81/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0420 - accuracy: 0.5613 - val_loss: 1.0375 - val_accuracy: 0.5759
# Epoch 82/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0363 - accuracy: 0.5633 - val_loss: 1.0367 - val_accuracy: 0.5767
# Epoch 83/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0277 - accuracy: 0.5723 - val_loss: 1.0528 - val_accuracy: 0.5506
# Epoch 84/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0370 - accuracy: 0.5614 - val_loss: 1.0383 - val_accuracy: 0.5742
# Epoch 85/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0289 - accuracy: 0.5665 - val_loss: 1.0362 - val_accuracy: 0.5865
# Epoch 86/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0325 - accuracy: 0.5630 - val_loss: 1.0326 - val_accuracy: 0.5726
# Epoch 87/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0288 - accuracy: 0.5666 - val_loss: 1.0314 - val_accuracy: 0.5775
# Epoch 88/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0246 - accuracy: 0.5741 - val_loss: 1.0435 - val_accuracy: 0.5644
# Epoch 89/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0309 - accuracy: 0.5665 - val_loss: 1.0413 - val_accuracy: 0.5669
# Epoch 90/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0280 - accuracy: 0.5705 - val_loss: 1.0330 - val_accuracy: 0.5775
# Epoch 91/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0299 - accuracy: 0.5673 - val_loss: 1.0346 - val_accuracy: 0.5685
# Epoch 92/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0240 - accuracy: 0.5733 - val_loss: 1.0342 - val_accuracy: 0.5840
# Epoch 93/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0199 - accuracy: 0.5721 - val_loss: 1.0340 - val_accuracy: 0.5644
# Epoch 94/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0214 - accuracy: 0.5766 - val_loss: 1.0321 - val_accuracy: 0.5750
# Epoch 95/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0254 - accuracy: 0.5779 - val_loss: 1.0326 - val_accuracy: 0.5693
# Epoch 96/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0219 - accuracy: 0.5764 - val_loss: 1.0378 - val_accuracy: 0.5726
# Epoch 97/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0234 - accuracy: 0.5743 - val_loss: 1.0254 - val_accuracy: 0.5856
# Epoch 98/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0207 - accuracy: 0.5694 - val_loss: 1.0276 - val_accuracy: 0.5750
# Epoch 99/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0096 - accuracy: 0.5835 - val_loss: 1.0307 - val_accuracy: 0.5791
# Epoch 100/175
# 55/55 [==============================] - 1s 20ms/step - loss: 1.0187 - accuracy: 0.5721 - val_loss: 1.0310 - val_accuracy: 0.5808
# Epoch 101/175
# 55/55 [==============================] - 1s 22ms/step - loss: 1.0155 - accuracy: 0.5813 - val_loss: 1.0316 - val_accuracy: 0.5848
# Epoch 102/175
# 55/55 [==============================] - 1s 23ms/step - loss: 1.0162 - accuracy: 0.5779 - val_loss: 1.0289 - val_accuracy: 0.5759
# Epoch 103/175
# 55/55 [==============================] - 1s 22ms/step - loss: 1.0146 - accuracy: 0.5823 - val_loss: 1.0299 - val_accuracy: 0.5759
# Epoch 104/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0178 - accuracy: 0.5815 - val_loss: 1.0283 - val_accuracy: 0.5701
# Epoch 105/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0183 - accuracy: 0.5741 - val_loss: 1.0288 - val_accuracy: 0.5710
# Epoch 106/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0108 - accuracy: 0.5829 - val_loss: 1.0271 - val_accuracy: 0.5718
# Epoch 107/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0131 - accuracy: 0.5751 - val_loss: 1.0268 - val_accuracy: 0.5767
# Epoch 108/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0099 - accuracy: 0.5813 - val_loss: 1.0234 - val_accuracy: 0.5848
# Epoch 109/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0092 - accuracy: 0.5812 - val_loss: 1.0220 - val_accuracy: 0.5856
# Epoch 110/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0080 - accuracy: 0.5803 - val_loss: 1.0319 - val_accuracy: 0.5742
# Epoch 111/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0094 - accuracy: 0.5790 - val_loss: 1.0212 - val_accuracy: 0.5824
# Epoch 112/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0120 - accuracy: 0.5780 - val_loss: 1.0270 - val_accuracy: 0.5710
# Epoch 113/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0101 - accuracy: 0.5816 - val_loss: 1.0254 - val_accuracy: 0.5881
# Epoch 114/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0078 - accuracy: 0.5897 - val_loss: 1.0217 - val_accuracy: 0.5750
# Epoch 115/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0001 - accuracy: 0.5870 - val_loss: 1.0219 - val_accuracy: 0.5889
# Epoch 116/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0075 - accuracy: 0.5862 - val_loss: 1.0209 - val_accuracy: 0.5889
# Epoch 117/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0028 - accuracy: 0.5920 - val_loss: 1.0175 - val_accuracy: 0.5856
# Epoch 118/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9970 - accuracy: 0.5896 - val_loss: 1.0150 - val_accuracy: 0.5856
# Epoch 119/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0095 - accuracy: 0.5851 - val_loss: 1.0234 - val_accuracy: 0.5718
# Epoch 120/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0110 - accuracy: 0.5832 - val_loss: 1.0159 - val_accuracy: 0.5897
# Epoch 121/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0050 - accuracy: 0.5901 - val_loss: 1.0165 - val_accuracy: 0.5914
# Epoch 122/175
# 55/55 [==============================] - 1s 18ms/step - loss: 1.0033 - accuracy: 0.5875 - val_loss: 1.0189 - val_accuracy: 0.5791
# Epoch 123/175
# 55/55 [==============================] - 1s 16ms/step - loss: 1.0027 - accuracy: 0.5900 - val_loss: 1.0237 - val_accuracy: 0.5873
# Epoch 124/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9955 - accuracy: 0.5956 - val_loss: 1.0207 - val_accuracy: 0.5767
# Epoch 125/175
# 55/55 [==============================] - 1s 15ms/step - loss: 1.0003 - accuracy: 0.5907 - val_loss: 1.0222 - val_accuracy: 0.5914
# Epoch 126/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9958 - accuracy: 0.5916 - val_loss: 1.0218 - val_accuracy: 0.5938
# Epoch 127/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9913 - accuracy: 0.5946 - val_loss: 1.0256 - val_accuracy: 0.5954
# Epoch 128/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9910 - accuracy: 0.5978 - val_loss: 1.0224 - val_accuracy: 0.5750
# Epoch 129/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9921 - accuracy: 0.5962 - val_loss: 1.0213 - val_accuracy: 0.5767
# Epoch 130/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9965 - accuracy: 0.5933 - val_loss: 1.0213 - val_accuracy: 0.5767
# Epoch 131/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9934 - accuracy: 0.5982 - val_loss: 1.0239 - val_accuracy: 0.5848
# Epoch 132/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9956 - accuracy: 0.5953 - val_loss: 1.0260 - val_accuracy: 0.5816
# Epoch 133/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9910 - accuracy: 0.6020 - val_loss: 1.0195 - val_accuracy: 0.5914
# Epoch 134/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9799 - accuracy: 0.6050 - val_loss: 1.0212 - val_accuracy: 0.5848
# Epoch 135/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9985 - accuracy: 0.5923 - val_loss: 1.0237 - val_accuracy: 0.5775
# Epoch 136/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9934 - accuracy: 0.5971 - val_loss: 1.0216 - val_accuracy: 0.5881
# Epoch 137/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9961 - accuracy: 0.5991 - val_loss: 1.0205 - val_accuracy: 0.5889
# Epoch 138/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9872 - accuracy: 0.5998 - val_loss: 1.0203 - val_accuracy: 0.5742
# Epoch 139/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9871 - accuracy: 0.6022 - val_loss: 1.0233 - val_accuracy: 0.5865
# Epoch 140/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9920 - accuracy: 0.5981 - val_loss: 1.0157 - val_accuracy: 0.5889
# Epoch 141/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9915 - accuracy: 0.5932 - val_loss: 1.0230 - val_accuracy: 0.5775
# Epoch 142/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9870 - accuracy: 0.5998 - val_loss: 1.0189 - val_accuracy: 0.5889
# Epoch 143/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9878 - accuracy: 0.5992 - val_loss: 1.0350 - val_accuracy: 0.5693
# Epoch 144/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9823 - accuracy: 0.6054 - val_loss: 1.0117 - val_accuracy: 0.5775
# Epoch 145/175
# 55/55 [==============================] - 1s 17ms/step - loss: 0.9778 - accuracy: 0.6021 - val_loss: 1.0201 - val_accuracy: 0.5693
# Epoch 146/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9883 - accuracy: 0.5999 - val_loss: 1.0155 - val_accuracy: 0.5734
# Epoch 147/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9780 - accuracy: 0.6070 - val_loss: 1.0157 - val_accuracy: 0.5848
# Epoch 148/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9823 - accuracy: 0.6040 - val_loss: 1.0196 - val_accuracy: 0.5848
# Epoch 149/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9841 - accuracy: 0.6030 - val_loss: 1.0157 - val_accuracy: 0.5914
# Epoch 150/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9793 - accuracy: 0.6080 - val_loss: 1.0171 - val_accuracy: 0.5840
# Epoch 151/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9753 - accuracy: 0.6048 - val_loss: 1.0209 - val_accuracy: 0.5783
# Epoch 152/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9774 - accuracy: 0.6048 - val_loss: 1.0209 - val_accuracy: 0.5799
# Epoch 153/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9826 - accuracy: 0.6063 - val_loss: 1.0179 - val_accuracy: 0.5865
# Epoch 154/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9781 - accuracy: 0.6031 - val_loss: 1.0162 - val_accuracy: 0.5816
# Epoch 155/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9807 - accuracy: 0.6082 - val_loss: 1.0137 - val_accuracy: 0.5922
# Epoch 156/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9803 - accuracy: 0.6028 - val_loss: 1.0159 - val_accuracy: 0.5816
# Epoch 157/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9780 - accuracy: 0.6060 - val_loss: 1.0094 - val_accuracy: 0.5962
# Epoch 158/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9754 - accuracy: 0.6048 - val_loss: 1.0189 - val_accuracy: 0.5971
# Epoch 159/175
# 55/55 [==============================] - 1s 17ms/step - loss: 0.9773 - accuracy: 0.6034 - val_loss: 1.0121 - val_accuracy: 0.5832
# Epoch 160/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9726 - accuracy: 0.6142 - val_loss: 1.0130 - val_accuracy: 0.5881
# Epoch 161/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9719 - accuracy: 0.6144 - val_loss: 1.0142 - val_accuracy: 0.5856
# Epoch 162/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9628 - accuracy: 0.6230 - val_loss: 1.0097 - val_accuracy: 0.5995
# Epoch 163/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9730 - accuracy: 0.6089 - val_loss: 1.0104 - val_accuracy: 0.5881
# Epoch 164/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9709 - accuracy: 0.6113 - val_loss: 1.0168 - val_accuracy: 0.5865
# Epoch 165/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9710 - accuracy: 0.6126 - val_loss: 1.0070 - val_accuracy: 0.6036
# Epoch 166/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9667 - accuracy: 0.6148 - val_loss: 1.0162 - val_accuracy: 0.5799
# Epoch 167/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9658 - accuracy: 0.6211 - val_loss: 1.0151 - val_accuracy: 0.5905
# Epoch 168/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9680 - accuracy: 0.6134 - val_loss: 1.0076 - val_accuracy: 0.5799
# Epoch 169/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9752 - accuracy: 0.6033 - val_loss: 1.0208 - val_accuracy: 0.5856
# Epoch 170/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9706 - accuracy: 0.6119 - val_loss: 1.0158 - val_accuracy: 0.5946
# Epoch 171/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9663 - accuracy: 0.6109 - val_loss: 1.0134 - val_accuracy: 0.5914
# Epoch 172/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9688 - accuracy: 0.6165 - val_loss: 1.0126 - val_accuracy: 0.5930
# Epoch 173/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9664 - accuracy: 0.6203 - val_loss: 1.0150 - val_accuracy: 0.5954
# Epoch 174/175
# 55/55 [==============================] - 1s 15ms/step - loss: 0.9664 - accuracy: 0.6161 - val_loss: 1.0178 - val_accuracy: 0.6003
# Epoch 175/175
# 55/55 [==============================] - 1s 16ms/step - loss: 0.9677 - accuracy: 0.6108 - val_loss: 1.0113 - val_accuracy: 0.5971

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test)
print('Test accuracy :', accuracy)
# Out:
# 10/10 [==============================] - 0s 12ms/step - loss: 1.0113 - accuracy: 0.5971
# Test accuracy : 0.5970636010169983

# %%
# Save the weights model.
model.save('./data/humanModel/model_v0.h5')

# %%
# save model in js format
# import tensorflowjs as tfjs
# tfjs.converters.save_keras_model(model, 'data/humanModel/js_model_v0')

# %%
# new_model = tf.keras.models.load_model('./data/humanModel/mode_v0')

# # Check its architecture
# new_model.summary()

# %% [markdown]
# ### Predict on new data

# %%
path = "./data/humanModel_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png"

img = keras.preprocessing.image.load_img(
    path, target_size=(IMG_SIZE, IMG_SIZE)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
img_array = img_array/255
predictions = model.predict(img_array)[0]

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(np.argmax(predictions), 100 * np.max(predictions))
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_256529/230040765.py in <module>
#       2
#       3 img = keras.preprocessing.image.load_img(
# ----> 4     path, target_size=(IMG_SIZE, IMG_SIZE)
#       5 )
#       6 img_array = keras.preprocessing.image.img_to_array(img)
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/humanModel_dataset_split/val/38/-Mr4e3Fomo72jz0zfTgB_14.png'
